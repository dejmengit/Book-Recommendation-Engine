# %%
import requests, time, pandas as pd
from pprint import pprint

BASE = "https://openlibrary.org"
HEADERS = {"User-Agent": "BookRecsEduBot/1.0 (+https://example.edu)"}
session = requests.Session(); session.headers.update(HEADERS)

# %%
# Start test
subjects = [
    "fiction",
    "fantasy",
    "mystery",
    "history",
    "science_fiction",
]
subjects
# Out:
# ['fiction', 'fantasy', 'mystery', 'history', 'science_fiction']

# %% [markdown]
# ## 2) Fetch ONE subject page (peek at the structure)

# %%
# Fetch ONE subject page

subject = subjects[0] 
offset = 0
limit = 20

url = f"{BASE}/subjects/{subject}.json?limit={limit}&offset={offset}"
print(url)
resp = session.get(url, timeout=30)
resp.raise_for_status()
data = resp.json()

print("Keys at top level:", list(data.keys()))
print("How many works returned:", len(data.get("works", [])))
pprint(data.get("works", [])[0])
# Out:
# https://openlibrary.org/subjects/fiction.json?limit=20&offset=0
# Keys at top level: ['key', 'name', 'subject_type', 'work_count', 'works']
# How many works returned: 20
# {'authors': [{'key': '/authors/OL21594A', 'name': 'Jane Austen'}],
#  'availability': {'__src__': 'core.models.lending.get_availability',
#                   'available_to_borrow': False,
#                   'available_to_browse': False,
#                   'available_to_waitlist': False,
#                   'identifier': 'bwb_KS-179-237',
#                   'is_browseable': False,
#                   'is_lendable': False,
#                   'is_previewable': True,
#                   'is_printdisabled': False,
#                   'is_readable': True,
#                   'is_restricted': False,
#                   'isbn': None,
#                   'last_loan_date': None,
#                   'last_waitlist_date': None,
#                   'num_waitlist': None,
#                   'oclc': None,
#                   'openlibrary_edition': 'OL50444320M',
#                   'openlibrary_work': 'OL66554W',
#                   'status': 'open'},
#  'cover_edition_key': 'OL47044678M',
#  'cover_id': 14348537,
#  'edition_count': 4036,
#  'first_publish_year': 1813,
#  'has_fulltext': True,
#  'ia': 'bwb_KS-179-237',
#  'ia_collection': ['365-Books-by-Women-Authors',
#                    'additional_collections',
#                    'americana',
#                    'americanuniversity-ol',
#                    'audio_bookspoetry',
#                    'belmont-ol',
#                    'binghamton-ol',
#                    'bpljordan-ol',
#                    'brucepeel',
#                    'cnusd-ol',
#                    'community',
#                    'cua-ol',
#                    'dartmouthlibrary-ol',
#                    'delawarecountydistrictlibrary',
#                    'delawarecountydistrictlibrary-ol',
#                    'denverpubliclibrary-ol',
#                    'drakeuniversity-ol',
#                    'duke_libraries',
#                    'emory',
#                    'framingham-ol',
#                    'georgetown-university-law-library-ol',
#                    'goffstownlibrary-ol',
#                    'gutenberg',
#                    'gutenberg-audiobooks',
#                    'gwulibraries-ol',
#                    'hamiltonpubliclibrary-ol',
#                    'inlibrary',
#                    'internetarchivebooks',
#                    'ithacacollege-ol',
#                    'johnshopkins-ol',
#                    'kalamazoocollege-ol',
#                    'kellylibrary',
#                    'library_of_congress',
#                    'librivoxaudio',
#                    'marygrovecollege',
#                    'miltonpubliclibrary-ol',
#                    'newyorkpubliclibrary',
#                    'occidentalcollegelibrary-ol',
#                    'openlibrary-d-ol',
#                    'opensource',
#                    'phillipsacademy-preview',
#                    'popularchinesebooks',
#                    'printdisabled',
#                    'randolph-macon-college-ol',
#                    'riceuniversity-ol',
#                    'robarts',
#                    'rochester-ol',
#                    'spokanepubliclibrary-ol',
#                    'stmaryscountylibrary',
#                    'the-claremont-colleges-ol',
#                    'toronto',
#                    'tulsacc-ol',
#                    'udc-ol',
#                    'unb-ol',
#                    'uni-ol',
#                    'university_of_alberta_libraries',
#                    'university_of_illinois_urbana-champaign',
#                    'university_of_toronto',
#                    'universityofcoloradoboulder-ol',
#                    'universityofoklahoma-ol',
#                    'uslprototype',
#                    'wilsoncollege-ol',
#                    'worthingtonlibraries-ol',
#                    'yellowbacks'],
#  'key': '/works/OL66554W',
#  'lending_edition': 'OL50444320M',
#  'lending_identifier': 'bwb_KS-179-237',
#  'printdisabled': True,
#  'public_scan': True,
#  'subject': ['Fiction, Romance, Historical, Regency',
#              'British and Irish fiction (fictional works by one author)',
#              'Brothers and sisters',
#              'Courtship',
#              'Drama',
#              'English fiction',
#              'English literature',
#              'Families',
#              'Family',
#              'Family life',
#              'Family relations',
#              'Fiction Classics',
#              'History',
#              'Interpersonal relations',
#              'Literary Fiction',
#              'Love stories',
#              'manners',
#              'Manners and customs',
#              'marriage',
#              'Sisters',
#              'Social classes',
#              'Social life and customs',
#              'Upper class',
#              'wealth',
#              'Women in England',
#              'young ladies',
#              'Young women',
#              'entail',
#              'Young women, fiction',
#              'Sisters, fiction',
#              'Fiction, family life, general',
#              'England, fiction',
#              'Man-woman relationships, fiction',
#              'Roman anglais',
#              'Classes sociales',
#              'Romans, nouvelles',
#              'Sœurs',
#              'Amours',
#              'Jeunes femmes',
#              'Familles',
#              'Mœurs et coutumes"',
#              'Clases sociales',
#              'Novela',
#              'Jóvenes (Mujeres)',
#              'Cortejo amoroso',
#              'Hermanas',
#              'Cuentos de amor',
#              'Fiction, coming of age',
#              'Fiction, romance, general',
#              'Great britain, social life and customs, fiction',
#              'Readers',
#              'Prejudices',
#              'Romance fiction',
#              'Historical fiction',
#              'Classical literature',
#              'Domestic fiction',
#              'English language, textbooks for foreign speakers',
#              'Women, fiction',
#              'Adaptations',
#              'Gentry',
#              'Mate selection',
#              'Fiction, romance, historical, general',
#              'English literature (collections)',
#              'Coloring books',
#              'Fiction, family life',
#              'Language and languages, study and teaching',
#              'Emoticons',
#              'Drama (dramatic works by one author)',
#              'Feelings',
#              'Class',
#              'Englisch',
#              'Roman',
#              'Sociala klasser i litteraturen',
#              'Prophecies',
#              'Great britain',
#              'Reading level-grade 7',
#              'Reading level-grade 9',
#              'Reading level-grade 8',
#              'Reading level-grade 11',
#              'Reading level-grade 10',
#              'Reading level-grade 12',
#              'Large type books',
#              'Fiction, romance, historical',
#              'Austen, jane, 1775-1817',
#              'Literature and fiction (general)',
#              'English literature, history and criticism',
#              'England',
#              'Художественная литература -- Великобритания -- Английская '
#              'литература -- 1-ая пол. 19 в. -- Романы',
#              'Novel',
#              'Fiction',
#              'Long Now Manual for Civilization',
#              'Elizabeth Bennet (Fictitious character)',
#              'Fitzwilliam Darcy (Fictitious character)',
#              'Pride and prejudice (Austen, Jane)',
#              'Mr. Collins (Fictitious character)'],
#  'title': 'Pride and Prejudice'}

# %%
# Normalize ONE work into a friendly Python dict
def normalize_work(work, subject_name):
    # Title & key
    title = work.get("title") or ""
    key = work.get("key") or ""

    # Authors list (names)
    authors = []
    for a in (work.get("authors") or []):
        name = a.get("name")
        if name:
            authors.append(name)
    authors_str = ", ".join(authors) if authors else None

    # Subjects/genres
    subjects_list = work.get("subject") or work.get("subjects") or []
    # Also include the subject we queried as a tag
    if subject_name.replace("_", " ") not in [str(s).lower() for s in subjects_list]:
        subjects_list = list(subjects_list) + [subject_name.replace("_", " ")]
    subjects_str = ", ".join(map(str, subjects_list[:20])) if subjects_list else None

    # first publish year & cover
    first_year = work.get("first_publish_year")
    cover_id = work.get("cover_id")
    cover_url = f"https://covers.openlibrary.org/b/id/{cover_id}-L.jpg" if isinstance(cover_id, int) else None

    return {
        "work_key": key,
        "title": title,
        "authors": authors_str,
        "subjects": subjects_str,
        "first_publish_year": first_year,
        "cover_url": cover_url
    }

sample = normalize_work(data["works"][0], subject)
pprint(sample)
# Out:
# {'authors': 'Jane Austen',
#  'cover_url': 'https://covers.openlibrary.org/b/id/14348537-L.jpg',
#  'first_publish_year': 1813,
#  'subjects': 'Fiction, Romance, Historical, Regency, British and Irish fiction '
#              '(fictional works by one author), Brothers and sisters, '
#              'Courtship, Drama, English fiction, English literature, Families, '
#              'Family, Family life, Family relations, Fiction Classics, '
#              'History, Interpersonal relations, Literary Fiction, Love '
#              'stories, manners, Manners and customs, marriage, Sisters',
#  'title': 'Pride and Prejudice',
#  'work_key': '/works/OL66554W'}

# %%
# Turn one subject page into a DF
rows = [normalize_work(w, subject) for w in data.get("works", [])]
df = pd.DataFrame(rows)
df.head()
# Out:
#             work_key                             title          authors  \
# 0    /works/OL66554W               Pride and Prejudice      Jane Austen
# 1   /works/OL138052W  Alice's Adventures in Wonderland    Lewis Carroll
# 2  /works/OL8193416W        The Picture of Dorian Gray      Oscar Wilde
# 3    /works/OL21177W                 Wuthering Heights    Emily Brontë
# 4  /works/OL8193497W                 A Christmas Carol  Charles Dickens
#
#                                             subjects  first_publish_year  \
# 0  Fiction, Romance, Historical, Regency, British...                1813
# 1  Alice (fictitious character : carroll), fictio...                1865
# 2  British and irish fiction (fictional works by ...                1890
# 3  British and irish fiction (fictional works by ...                1846
# 4  Ghost stories, Readers, Ebenzer Scrooge (Ficti...                1843
#
#                                            cover_url
# 0  https://covers.openlibrary.org/b/id/14348537-L...
# 1  https://covers.openlibrary.org/b/id/10527843-L...
# 2  https://covers.openlibrary.org/b/id/14314858-L...
# 3  https://covers.openlibrary.org/b/id/12818862-L...
# 4  https://covers.openlibrary.org/b/id/13299222-L...

# %%
 # collect a few pages
def fetch_subject(subject, target=100, per_page=50, sleep=0.2):
    rows = []
    seen = set()
    offset = 0
    while len(rows) < target:
        url = f"{BASE}/subjects/{subject}.json?limit={per_page}&offset={offset}"
        r = session.get(url, timeout=30)
        r.raise_for_status()
        js = r.json()
        works = js.get("works", [])
        if not works:
            break
        for w in works:
            rec = normalize_work(w, subject)
            if rec["work_key"] and rec["work_key"] not in seen:
                seen.add(rec["work_key"])
                rows.append(rec)
                if len(rows) >= target:
                    break
        offset += per_page
        time.sleep(sleep)
    return pd.DataFrame(rows)

demo_df = fetch_subject("fiction", target=150, per_page=50)
len(demo_df), demo_df.head(3)
# Out:
# (150,
#              work_key                             title        authors  \
#  0    /works/OL66554W               Pride and Prejudice    Jane Austen
#  1   /works/OL138052W  Alice's Adventures in Wonderland  Lewis Carroll
#  2  /works/OL8193416W        The Picture of Dorian Gray    Oscar Wilde
#
#                                              subjects  first_publish_year  \
#  0  Fiction, Romance, Historical, Regency, British...                1813
#  1  Alice (fictitious character : carroll), fictio...                1865
#  2  British and irish fiction (fictional works by ...                1890
#
#                                             cover_url
#  0  https://covers.openlibrary.org/b/id/14348537-L...
#  1  https://covers.openlibrary.org/b/id/10527843-L...
#  2  https://covers.openlibrary.org/b/id/14314858-L...  )

# %%
 # Combine subjects 
def collect(subjects, target_total=300, per_page=50, sleep=0.2):
    all_rows = []
    seen = set()
    for subj in subjects:
        if len(all_rows) >= target_total: break
        part = fetch_subject(subj, target=max(50, target_total//len(subjects)), per_page=per_page, sleep=sleep)
        for _, row in part.iterrows():
            if row["work_key"] in seen:
                continue
            seen.add(row["work_key"])
            all_rows.append(row.to_dict())
    df_all = pd.DataFrame(all_rows)
    return df_all

small_df = collect(subjects, target_total=300, per_page=50)
len(small_df), small_df.head(3)
# Out:
# (240,
#              work_key                             title        authors  \
#  0    /works/OL66554W               Pride and Prejudice    Jane Austen
#  1   /works/OL138052W  Alice's Adventures in Wonderland  Lewis Carroll
#  2  /works/OL8193416W        The Picture of Dorian Gray    Oscar Wilde
#
#                                              subjects  first_publish_year  \
#  0  Fiction, Romance, Historical, Regency, British...                1813
#  1  Alice (fictitious character : carroll), fictio...                1865
#  2  British and irish fiction (fictional works by ...                1890
#
#                                             cover_url
#  0  https://covers.openlibrary.org/b/id/14348537-L...
#  1  https://covers.openlibrary.org/b/id/10527843-L...
#  2  https://covers.openlibrary.org/b/id/14314858-L...  )

# %%
# Save a small 249 rows CSV 
small_df.to_csv("openlibrary_small_checkpoint.csv", index=False)
print("Saved", len(small_df), "rows -> openlibrary_small_checkpoint.csv")
# Out:
# Saved 240 rows -> openlibrary_small_checkpoint.csv

# %%
# Scale up to 2k rows
bigger_subjects = subjects + ["romance", "young_adult", "biography", "horror", "philosophy", "science"]
big_df = collect(bigger_subjects, target_total=2000, per_page=100, sleep=0.2)
print("Total rows collected:", len(big_df))
big_df.head(3)
# Out:
# Total rows collected: 1658
#             work_key                             title        authors  \
# 0    /works/OL66554W               Pride and Prejudice    Jane Austen
# 1   /works/OL138052W  Alice's Adventures in Wonderland  Lewis Carroll
# 2  /works/OL8193416W        The Picture of Dorian Gray    Oscar Wilde
#
#                                             subjects  first_publish_year  \
# 0  Fiction, Romance, Historical, Regency, British...                1813
# 1  Alice (fictitious character : carroll), fictio...                1865
# 2  British and irish fiction (fictional works by ...                1890
#
#                                            cover_url
# 0  https://covers.openlibrary.org/b/id/14348537-L...
# 1  https://covers.openlibrary.org/b/id/10527843-L...
# 2  https://covers.openlibrary.org/b/id/14314858-L...

# %%
# Drop exact duplicates by work key
big_df = big_df.drop_duplicates(subset=["work_key"]).reset_index(drop=True)

# Keep essential columns
cols = ["work_key","title","authors","subjects","first_publish_year","cover_url"]
for c in cols:
    if c not in big_df.columns:
        big_df[c] = None
big_df = big_df[cols]

print("After dedupe:", len(big_df))
big_df.sample(5)
# Out:
# After dedupe: 1658
#                 work_key                    title  \
# 257    /works/OL7989179W   Vikram and the Vampire
# 1480    /works/OL100196W             The "genius"
# 150      /works/OL81180W  Lady Chatterley's Lover
# 1615  /works/OL21331191W    Handbook of Flowering
# 1559  /works/OL17095301W                 What If?
#
#                                                 authors  \
# 257   Richard Francis Burton, Ernest Henry Griset, I...
# 1480                                   Theodore Dreiser
# 150                                      D. H. Lawrence
# 1615                                  Abraham H. Halevy
# 1559                                     Randall Munroe
#
#                                                subjects  first_publish_year  \
# 257   Fantasy, Fiction, Historical Fiction, Classic ...                1870
# 1480  American fiction, Translations into Russian, R...                1915
# 150   Sexual behavior, Married women, Adultery, Nobi...                1900
# 1615  Cultivated Plants, Handbooks, manuals, Floweri...                2017
# 1559  Mathematics, Statistics, Miscellanea, Science,...                1980
#
#                                               cover_url
# 257   https://covers.openlibrary.org/b/id/1758137-L.jpg
# 1480  https://covers.openlibrary.org/b/id/8369941-L.jpg
# 150   https://covers.openlibrary.org/b/id/12983362-L...
# 1615  https://covers.openlibrary.org/b/id/13300590-L...
# 1559  https://covers.openlibrary.org/b/id/9083979-L.jpg

# %%
# save big csv
big_df.to_csv("openlibrary_books.csv", index=False)
print("Saved -> openlibrary_books.csv with", len(big_df), "rows")
# Out:
# Saved -> openlibrary_books.csv with 1658 rows

# %%
# Top subjects (split the comma-separated list)
from collections import Counter
subj_counter = Counter()
for s in big_df["subjects"].dropna():
    for tok in map(str.strip, s.split(",")):
        if tok:
            subj_counter[tok.lower()] += 1

pd.DataFrame(subj_counter.most_common(20), columns=["subject","count"])
# Out:
#                 subject  count
# 0               fiction   3818
# 1               general    693
# 2               history    349
# 3       science fiction    346
# 4               fantasy    344
# 5               romance    313
# 6      juvenile fiction    278
# 7   mystery & detective    268
# 8    classic literature    255
# 9    children's fiction    254
# 10               horror    247
# 11           philosophy    239
# 12     large type books    208
# 13            biography    199
# 14              science    186
# 15              mystery    185
# 16          young adult    170
# 17           historical    164
# 18   english literature    161
# 19      fantasy fiction    150
